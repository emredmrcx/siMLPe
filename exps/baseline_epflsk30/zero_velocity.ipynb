# %%
import pandas as pd
import numpy as np
import copy
import torch

from config import config
from datasets.epfl_sk30 import EPFLSK30Dataset
from torch.utils.data import DataLoader
from datasets.epfl_sk30_eval import EPFLSK30Eval

# %%
# Configuration
results_keys = ['#2', '#4', '#8', '#10', '#14', '#18', '#22', '#25']

# Joint names for EPFL-SK30 dataset
joint_names = [
    'Root',
    'LeftHead',
    'RightHead',
    'LeftBody',
    'RightBody',
    'LeftShoulder',
    'RightShoulder',
    'LeftArm',
    'RightArm',
    'LeftForearm',
    'RightForearm',
    'LeftHip',
    'RightHip',
    'LeftKnee',
    'RightKnee',
    'LeftFoot',
    'RightFoot'
]

# %%
def compute_zero_velocity_baseline(dataloader, target_length, config):
    """
    Compute zero velocity baseline by repeating the last observed frame.
    
    Args:
        dataloader: DataLoader for the dataset
        target_length: Number of future frames to predict
        config: Configuration object
        
    Returns:
        ret: Dictionary with average MPJPE per timestep
        ret_per_joint: Dictionary with MPJPE per joint per timestep
    """
    m_p3d_h36_per_joint = np.zeros([target_length, 17])  # 17 joints
    num_samples = 0
    
    for (motion_t, motion_t_1) in dataloader:
        b, n, c, _ = motion_t.shape
        num_samples += b
        
        # motion_t[:, 49, :, :] has shape (b, 17, 3) - last observed frame
        # Expand to (b, target_length, 17, 3)
        motion_pred = motion_t[:, config.motion.epfl_input_length - 1, :, :].unsqueeze(1).repeat(1, target_length, 1, 1)
        motion_gt = motion_t_1
        
        # Calculate MPJPE per joint for each timestep
        # dim=3: L2 norm over (x,y,z) -> (b, target_length, 17)
        # dim=0: sum over batch -> (target_length, 17)
        mpjpe_p3d_h36_per_joint = torch.sum(torch.norm(motion_pred*1000 - motion_gt*1000, dim=3), dim=0)
        m_p3d_h36_per_joint += mpjpe_p3d_h36_per_joint.cpu().numpy()
        
    m_p3d_h36_per_joint = m_p3d_h36_per_joint / num_samples
    m_p3d_h36 = m_p3d_h36_per_joint.mean(axis=1)
    
    titles = np.array(range(target_length)) + 1
    ret = {}
    ret_per_joint = {}
    for j in range(target_length):
        ret["#{:d}".format(titles[j])] = m_p3d_h36[j]
        ret_per_joint["#{:d}".format(titles[j])] = m_p3d_h36_per_joint[j]
    
    return ret, ret_per_joint

# %%
eval_dataset = EPFLSK30Eval(config, 'test')
eval_dataloader = DataLoader(eval_dataset, batch_size=256,
                        num_workers=16, drop_last=True,
                        sampler=None, shuffle=False, pin_memory=True)
print(f"Length of test dataloader: {len(eval_dataloader)}")
# Out:
# Length of test dataloader: 2099

# %%
# To evaluate the training set in up to 25 frames
config.motion.epfl_target_length_train = 25

dataset = EPFLSK30Dataset(config, 'train', config.data_aug)
dataloader = DataLoader(dataset, batch_size=256,
                        num_workers=16, drop_last=False,
                        sampler=None, shuffle=False, pin_memory=True)
print(f"Length of train dataloader: {len(dataloader)}")
# Out:
# Length of train dataloader: 4352

# %%
# Compute zero velocity baseline for training set
ret_train, ret_per_joint_train = compute_zero_velocity_baseline(dataloader, config.motion.epfl_target_length_train, config)

# %%
print("Zero Velocity Baseline Results for Training Set:")
print([key for key in results_keys])
print([round(ret_train[key], 1) for key in results_keys])

print("\n" + "="*60)
print("Per-Joint Errors for each timestep:")
print("="*60)
for key in results_keys:
    print(f"\nTimestep {key}:")
    per_joint_errors = ret_per_joint_train[key]
    for joint_idx in range(len(per_joint_errors)):
        print(f"  Joint {joint_idx:2d} ({joint_names[joint_idx]:13s}): {per_joint_errors[joint_idx]:.3f} mm")
    print(f"  Average: {ret_train[key]:.3f} mm")
# Out:
# Zero Velocity Baseline Results for Training Set:
# ['#2', '#4', '#8', '#10', '#14', '#18', '#22', '#25']
# [20.3, 38.4, 70.3, 84.8, 111.1, 134.7, 156.1, 170.9]
#
# ============================================================
# Per-Joint Errors for each timestep:
# ============================================================
#
# Timestep #2:
#   Joint  0 (Root): 20.500 mm
#   Joint  1 (LeftHead): 20.222 mm
#   Joint  2 (RightHead): 20.248 mm
#   Joint  3 (LeftBody): 19.747 mm
#   Joint  4 (RightBody): 19.787 mm
#   Joint  5 (LeftShoulder): 20.032 mm
#   Joint  6 (RightShoulder): 21.243 mm
#   Joint  7 (LeftArm): 23.361 mm
#   Joint  8 (RightArm): 28.295 mm
#   Joint  9 (LeftForearm): 27.556 mm
#   Joint 10 (RightForearm): 34.358 mm
#   Joint 11 (LeftHip): 16.609 mm
#   Joint 12 (RightHip): 17.130 mm
#   Joint 13 (LeftKnee): 14.728 mm
#   Joint 14 (RightKnee): 15.468 mm
#   Joint 15 (LeftFoot): 12.909 mm
#   Joint 16 (RightFoot): 13.750 mm
#   Average: 20.350 mm
#
# Timestep #4:
#   Joint  0 (Root): 39.346 mm
#   Joint  1 (LeftHead): 39.002 mm
#   Joint  2 (RightHead): 39.023 mm
#   Joint  3 (LeftBody): 37.711 mm
#   Joint  4 (RightBody): 37.833 mm
#   Joint  5 (LeftShoulder): 37.605 mm
#   Joint  6 (RightShoulder): 39.916 mm
#   Joint  7 (LeftArm): 44.284 mm
#   Joint  8 (RightArm): 52.819 mm
#   Joint  9 (LeftForearm): 52.139 mm
#   Joint 10 (RightForearm): 63.657 mm
#   Joint 11 (LeftHip): 31.287 mm
#   Joint 12 (RightHip): 32.181 mm
#   Joint 13 (LeftKnee): 27.754 mm
#   Joint 14 (RightKnee): 29.182 mm
#   Joint 15 (LeftFoot): 23.948 mm
#   Joint 16 (RightFoot): 25.569 mm
#   Average: 38.427 mm
#
# Timestep #8:
#   Joint  0 (Root): 73.985 mm
#   Joint  1 (LeftHead): 73.649 mm
#   Joint  2 (RightHead): 73.684 mm
#   Joint  3 (LeftBody): 70.659 mm
#   Joint  4 (RightBody): 70.988 mm
#   Joint  5 (LeftShoulder): 68.901 mm
#   Joint  6 (RightShoulder): 73.001 mm
#   Joint  7 (LeftArm): 80.738 mm
#   Joint  8 (RightArm): 93.954 mm
#   Joint  9 (LeftForearm): 94.594 mm
#   Joint 10 (RightForearm): 111.437 mm
#   Joint 11 (LeftHip): 57.401 mm
#   Joint 12 (RightHip): 58.931 mm
#   Joint 13 (LeftKnee): 50.808 mm
#   Joint 14 (RightKnee): 53.519 mm
#   Joint 15 (LeftFoot): 43.293 mm
#   Joint 16 (RightFoot): 46.363 mm
#   Average: 70.347 mm
#
# Timestep #10:
#   Joint  0 (Root): 89.969 mm
#   Joint  1 (LeftHead): 89.653 mm
#   Joint  2 (RightHead): 89.701 mm
#   Joint  3 (LeftBody): 85.847 mm
#   Joint  4 (RightBody): 86.287 mm
#   Joint  5 (LeftShoulder): 83.024 mm
#   Joint  6 (RightShoulder): 87.911 mm
#   Joint  7 (LeftArm): 96.766 mm
#   Joint  8 (RightArm): 111.664 mm
#   Joint  9 (LeftForearm): 113.252 mm
#   Joint 10 (RightForearm): 131.797 mm
#   Joint 11 (LeftHip): 69.324 mm
#   Joint 12 (RightHip): 71.159 mm
#   Joint 13 (LeftKnee): 61.367 mm
#   Joint 14 (RightKnee): 64.722 mm
#   Joint 15 (LeftFoot): 52.289 mm
#   Joint 16 (RightFoot): 56.053 mm
#   Average: 84.752 mm
#
# Timestep #14:
#   Joint  0 (Root): 119.491 mm
#   Joint  1 (LeftHead): 119.208 mm
#   Joint  2 (RightHead): 119.289 mm
#   Joint  3 (LeftBody): 113.842 mm
#   Joint  4 (RightBody): 114.489 mm
#   Joint  5 (LeftShoulder): 108.679 mm
#   Joint  6 (RightShoulder): 115.015 mm
#   Joint  7 (LeftArm): 125.308 mm
#   Joint  8 (RightArm): 142.990 mm
#   Joint  9 (LeftForearm): 146.672 mm
#   Joint 10 (RightForearm): 167.735 mm
#   Joint 11 (LeftHip): 91.342 mm
#   Joint 12 (RightHip): 93.771 mm
#   Joint 13 (LeftKnee): 81.153 mm
#   Joint 14 (RightKnee): 85.695 mm
#   Joint 15 (LeftFoot): 69.498 mm
#   Joint 16 (RightFoot): 74.506 mm
#   Average: 111.099 mm
#
# Timestep #18:
#   Joint  0 (Root): 146.072 mm
#   Joint  1 (LeftHead): 145.785 mm
#   Joint  2 (RightHead): 145.937 mm
#   Joint  3 (LeftBody): 138.941 mm
#   Joint  4 (RightBody): 139.851 mm
#   Joint  5 (LeftShoulder): 131.434 mm
#   Joint  6 (RightShoulder): 139.141 mm
#   Joint  7 (LeftArm): 150.164 mm
#   Joint  8 (RightArm): 170.237 mm
#   Joint  9 (LeftForearm): 175.921 mm
#   Joint 10 (RightForearm): 198.870 mm
#   Joint 11 (LeftHip): 111.312 mm
#   Joint 12 (RightHip): 114.357 mm
#   Joint 13 (LeftKnee): 99.450 mm
#   Joint 14 (RightKnee): 105.063 mm
#   Joint 15 (LeftFoot): 85.851 mm
#   Joint 16 (RightFoot): 91.887 mm
#   Average: 134.722 mm
#
# Timestep #22:
#   Joint  0 (Root): 170.128 mm
#   Joint  1 (LeftHead): 169.818 mm
#   Joint  2 (RightHead): 170.057 mm
#   Joint  3 (LeftBody): 161.561 mm
#   Joint  4 (RightBody): 162.758 mm
#   Joint  5 (LeftShoulder): 151.856 mm
#   Joint  6 (RightShoulder): 160.824 mm
#   Joint  7 (LeftArm): 172.190 mm
#   Joint  8 (RightArm): 194.347 mm
#   Joint  9 (LeftForearm): 201.917 mm
#   Joint 10 (RightForearm): 226.253 mm
#   Joint 11 (LeftHip): 129.538 mm
#   Joint 12 (RightHip): 133.204 mm
#   Joint 13 (LeftKnee): 116.450 mm
#   Joint 14 (RightKnee): 123.036 mm
#   Joint 15 (LeftFoot): 101.296 mm
#   Joint 16 (RightFoot): 108.337 mm
#   Average: 156.092 mm
#
# Timestep #25:
#   Joint  0 (Root): 186.777 mm
#   Joint  1 (LeftHead): 186.436 mm
#   Joint  2 (RightHead): 186.760 mm
#   Joint  3 (LeftBody): 177.155 mm
#   Joint  4 (RightBody): 178.601 mm
#   Joint  5 (LeftShoulder): 165.877 mm
#   Joint  6 (RightShoulder): 175.804 mm
#   Joint  7 (LeftArm): 187.167 mm
#   Joint  8 (RightArm): 210.812 mm
#   Joint  9 (LeftForearm): 219.557 mm
#   Joint 10 (RightForearm): 244.829 mm
#   Joint 11 (LeftHip): 142.266 mm
#   Joint 12 (RightHip): 146.421 mm
#   Joint 13 (LeftKnee): 128.414 mm
#   Joint 14 (RightKnee): 135.759 mm
#   Joint 15 (LeftFoot): 112.193 mm
#   Joint 16 (RightFoot): 120.068 mm
#   Average: 170.876 mm

# %%
# Compute zero velocity baseline for test set
ret_eval, ret_per_joint_eval = compute_zero_velocity_baseline(eval_dataloader, config.motion.epfl_target_length_eval, config)

# %%
print("Zero Velocity Baseline Results for Test Set:")
print([key for key in results_keys])
print([round(ret_eval[key], 1) for key in results_keys])

print("\n" + "="*60)
print("Per-Joint Errors for each timestep:")
print("="*60)
for key in results_keys:
    print(f"\nTimestep {key}:")
    per_joint_errors = ret_per_joint_eval[key]
    for joint_idx in range(len(per_joint_errors)):
        print(f"  Joint {joint_idx:2d} ({joint_names[joint_idx]:13s}): {per_joint_errors[joint_idx]:.3f} mm")
    print(f"  Average: {ret_eval[key]:.3f} mm")
# Out:
# Zero Velocity Baseline Results for Test Set:
# ['#2', '#4', '#8', '#10', '#14', '#18', '#22', '#25']
# [18.8, 35.4, 64.4, 77.4, 101.1, 122.2, 141.2, 154.4]
#
# ============================================================
# Per-Joint Errors for each timestep:
# ============================================================
#
# Timestep #2:
#   Joint  0 (Root         ): 18.350 mm
#   Joint  1 (LeftHead     ): 18.030 mm
#   Joint  2 (RightHead    ): 18.095 mm
#   Joint  3 (LeftBody     ): 17.686 mm
#   Joint  4 (RightBody    ): 17.835 mm
#   Joint  5 (LeftShoulder ): 17.936 mm
#   Joint  6 (RightShoulder): 19.405 mm
#   Joint  7 (LeftArm      ): 20.845 mm
#   Joint  8 (RightArm     ): 26.670 mm
#   Joint  9 (LeftForearm  ): 24.766 mm
#   Joint 10 (RightForearm ): 33.034 mm
#   Joint 11 (LeftHip      ): 15.725 mm
#   Joint 12 (RightHip     ): 16.274 mm
#   Joint 13 (LeftKnee     ): 13.911 mm
#   Joint 14 (RightKnee    ): 14.891 mm
#   Joint 15 (LeftFoot     ): 12.399 mm
#   Joint 16 (RightFoot    ): 13.405 mm
#   Average: 18.780 mm
#
# Timestep #4:
#   Joint  0 (Root         ): 35.129 mm
#   Joint  1 (LeftHead     ): 34.663 mm
#   Joint  2 (RightHead    ): 34.775 mm
#   Joint  3 (LeftBody     ): 33.631 mm
#   Joint  4 (RightBody    ): 33.963 mm
#   Joint  5 (LeftShoulder ): 33.613 mm
#   Joint  6 (RightShoulder): 36.496 mm
#   Joint  7 (LeftArm      ): 39.491 mm
#   Joint  8 (RightArm     ): 49.765 mm
#   Joint  9 (LeftForearm  ): 46.705 mm
#   Joint 10 (RightForearm ): 61.109 mm
#   Joint 11 (LeftHip      ): 29.571 mm
#   Joint 12 (RightHip     ): 30.479 mm
#   Joint 13 (LeftKnee     ): 26.140 mm
#   Joint 14 (RightKnee    ): 27.988 mm
#   Joint 15 (LeftFoot     ): 22.920 mm
#   Joint 16 (RightFoot    ): 24.820 mm
#   Average: 35.368 mm
#
# Timestep #8:
#   Joint  0 (Root         ): 65.862 mm
#   Joint  1 (LeftHead     ): 65.275 mm
#   Joint  2 (RightHead    ): 65.475 mm
#   Joint  3 (LeftBody     ): 62.751 mm
#   Joint  4 (RightBody    ): 63.475 mm
#   Joint  5 (LeftShoulder ): 61.309 mm
#   Joint  6 (RightShoulder): 66.675 mm
#   Joint  7 (LeftArm      ): 71.876 mm
#   Joint  8 (RightArm     ): 88.380 mm
#   Joint  9 (LeftForearm  ): 84.436 mm
#   Joint 10 (RightForearm ): 106.619 mm
#   Joint 11 (LeftHip      ): 53.854 mm
#   Joint 12 (RightHip     ): 55.351 mm
#   Joint 13 (LeftKnee     ): 47.410 mm
#   Joint 14 (RightKnee    ): 50.798 mm
#   Joint 15 (LeftFoot     ): 41.137 mm
#   Joint 16 (RightFoot    ): 44.555 mm
#   Average: 64.426 mm
#
# Timestep #10:
#   Joint  0 (Root         ): 79.985 mm
#   Joint  1 (LeftHead     ): 79.369 mm
#   Joint  2 (RightHead    ): 79.611 mm
#   Joint  3 (LeftBody     ): 76.137 mm
#   Joint  4 (RightBody    ): 77.032 mm
#   Joint  5 (LeftShoulder ): 73.763 mm
#   Joint  6 (RightShoulder): 80.205 mm
#   Joint  7 (LeftArm      ): 86.077 mm
#   Joint  8 (RightArm     ): 104.931 mm
#   Joint  9 (LeftForearm  ): 100.960 mm
#   Joint 10 (RightForearm ): 125.905 mm
#   Joint 11 (LeftHip      ): 64.797 mm
#   Joint 12 (RightHip     ): 66.576 mm
#   Joint 13 (LeftKnee     ): 57.016 mm
#   Joint 14 (RightKnee    ): 61.102 mm
#   Joint 15 (LeftFoot     ): 49.474 mm
#   Joint 16 (RightFoot    ): 53.568 mm
#   Average: 77.442 mm
#
# Timestep #14:
#   Joint  0 (Root         ): 105.989 mm
#   Joint  1 (LeftHead     ): 105.327 mm
#   Joint  2 (RightHead    ): 105.651 mm
#   Joint  3 (LeftBody     ): 100.732 mm
#   Joint  4 (RightBody    ): 101.924 mm
#   Joint  5 (LeftShoulder ): 96.338 mm
#   Joint  6 (RightShoulder): 104.656 mm
#   Joint  7 (LeftArm      ): 111.368 mm
#   Joint  8 (RightArm     ): 133.916 mm
#   Joint  9 (LeftForearm  ): 130.508 mm
#   Joint 10 (RightForearm ): 159.535 mm
#   Joint 11 (LeftHip      ): 84.790 mm
#   Joint 12 (RightHip     ): 87.135 mm
#   Joint 13 (LeftKnee     ): 74.790 mm
#   Joint 14 (RightKnee    ): 80.186 mm
#   Joint 15 (LeftFoot     ): 65.220 mm
#   Joint 16 (RightFoot    ): 70.555 mm
#   Average: 101.095 mm
#
# Timestep #18:
#   Joint  0 (Root         ): 129.358 mm
#   Joint  1 (LeftHead     ): 128.656 mm
#   Joint  2 (RightHead    ): 129.057 mm
#   Joint  3 (LeftBody     ): 122.758 mm
#   Joint  4 (RightBody    ): 124.213 mm
#   Joint  5 (LeftShoulder ): 116.293 mm
#   Joint  6 (RightShoulder): 126.246 mm
#   Joint  7 (LeftArm      ): 133.384 mm
#   Joint  8 (RightArm     ): 158.886 mm
#   Joint  9 (LeftForearm  ): 156.412 mm
#   Joint 10 (RightForearm ): 188.362 mm
#   Joint 11 (LeftHip      ): 102.765 mm
#   Joint 12 (RightHip     ): 105.661 mm
#   Joint 13 (LeftKnee     ): 91.082 mm
#   Joint 14 (RightKnee    ): 97.690 mm
#   Joint 15 (LeftFoot     ): 79.961 mm
#   Joint 16 (RightFoot    ): 86.481 mm
#   Average: 122.192 mm
#
# Timestep #22:
#   Joint  0 (Root         ): 150.520 mm
#   Joint  1 (LeftHead     ): 149.773 mm
#   Joint  2 (RightHead    ): 150.244 mm
#   Joint  3 (LeftBody     ): 142.614 mm
#   Joint  4 (RightBody    ): 144.328 mm
#   Joint  5 (LeftShoulder ): 134.166 mm
#   Joint  6 (RightShoulder): 145.606 mm
#   Joint  7 (LeftArm      ): 152.884 mm
#   Joint  8 (RightArm     ): 180.895 mm
#   Joint  9 (LeftForearm  ): 179.381 mm
#   Joint 10 (RightForearm ): 213.678 mm
#   Joint 11 (LeftHip      ): 119.123 mm
#   Joint 12 (RightHip     ): 122.571 mm
#   Joint 13 (LeftKnee     ): 106.177 mm
#   Joint 14 (RightKnee    ): 113.908 mm
#   Joint 15 (LeftFoot     ): 93.758 mm
#   Joint 16 (RightFoot    ): 101.426 mm
#   Average: 141.238 mm
#
# Timestep #25:
#   Joint  0 (Root         ): 165.138 mm
#   Joint  1 (LeftHead     ): 164.354 mm
#   Joint  2 (RightHead    ): 164.874 mm
#   Joint  3 (LeftBody     ): 156.298 mm
#   Joint  4 (RightBody    ): 158.194 mm
#   Joint  5 (LeftShoulder ): 146.461 mm
#   Joint  6 (RightShoulder): 158.912 mm
#   Joint  7 (LeftArm      ): 166.187 mm
#   Joint  8 (RightArm     ): 195.850 mm
#   Joint  9 (LeftForearm  ): 195.022 mm
#   Joint 10 (RightForearm ): 230.765 mm
#   Joint 11 (LeftHip      ): 130.503 mm
#   Joint 12 (RightHip     ): 134.379 mm
#   Joint 13 (LeftKnee     ): 116.820 mm
#   Joint 14 (RightKnee    ): 125.323 mm
#   Joint 15 (LeftFoot     ): 103.535 mm
#   Joint 16 (RightFoot    ): 112.000 mm
#   Average: 154.389 mm
